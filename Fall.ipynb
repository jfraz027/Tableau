# %%
import pandas as pd

# %%
df_JCcitibike_tripdata_e = pd.read_csv("JC-201810-citibike-tripdata.csv")
df_JCcitibike_tripdata_f = pd.read_csv("JC-201811-citibike-tripdata.csv")
df_JCcitibike_tripdata_g = pd.read_csv("JC-201812-citibike-tripdata.csv")

# %%
print(df_JCcitibike_tripdata_e)
print(df_JCcitibike_tripdata_f)
print(df_JCcitibike_tripdata_g)
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               152  2018-10-01 07:44:41.4170  2018-10-01 07:47:14.2960
# 1               122  2018-10-01 08:50:05.4340  2018-10-01 08:52:08.2250
# 2               211  2018-10-01 09:03:17.0640  2018-10-01 09:06:48.0940
# 3               342  2018-10-01 10:13:07.0090  2018-10-01 10:18:49.8960
# 4              2976  2018-10-01 10:45:14.2800  2018-10-01 11:34:51.2610
# ...             ...                       ...                       ...
# 39133          1118  2018-10-31 11:30:53.7070  2018-10-31 11:49:32.4850
# 39134          1242  2018-10-31 12:20:41.6990  2018-10-31 12:41:24.4270
# 39135          1188  2018-10-31 12:21:36.2790  2018-10-31 12:41:24.3540
# 39136           983  2018-10-31 14:27:59.9590  2018-10-31 14:44:23.2020
# 39137           544  2018-10-31 15:37:41.3760  2018-10-31 15:46:45.5090
#
#        start station id start station name  start station latitude  \
# ...

# %%
falldf_all_rows = pd.concat([df_JCcitibike_tripdata_e,df_JCcitibike_tripdata_f,df_JCcitibike_tripdata_g])
falldf_all_rows
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               152  2018-10-01 07:44:41.4170  2018-10-01 07:47:14.2960
# 1               122  2018-10-01 08:50:05.4340  2018-10-01 08:52:08.2250
# 2               211  2018-10-01 09:03:17.0640  2018-10-01 09:06:48.0940
# 3               342  2018-10-01 10:13:07.0090  2018-10-01 10:18:49.8960
# 4              2976  2018-10-01 10:45:14.2800  2018-10-01 11:34:51.2610
# ...             ...                       ...                       ...
# 20200          1081  2018-12-22 11:51:46.0600  2018-12-22 12:09:47.4730
# 20201           344  2018-12-25 21:40:09.8660  2018-12-25 21:45:54.2670
# 20202          1233  2018-12-29 12:55:45.9690  2018-12-29 13:16:19.5960
# 20203          1057  2018-12-30 15:32:09.3320  2018-12-30 15:49:46.3510
# 20204           301  2018-12-31 16:34:11.9340  2018-12-31 16:39:13.8340
#
#        start station id start station name  start station latitude  \
# ...

# %%
falldf_all_rows.to_csv("Datafile/Fall.csv", index=False, header=True)
