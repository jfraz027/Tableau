# %%
import pandas as pd

# %%
df_JCcitibike_tripdata_a = pd.read_csv("JC-201801-citibike-tripdata.csv")
df_JCcitibike_tripdata_b = pd.read_csv("JC-201802-citibike-tripdata.csv")
df_JCcitibike_tripdata_c = pd.read_csv("JC-201803-citibike-tripdata.csv")
df_JCcitibike_tripdata_d = pd.read_csv("JC-201804-citibike-tripdata.csv")
df_JCcitibike_tripdata_e = pd.read_csv("JC-201805-citibike-tripdata.csv")
df_JCcitibike_tripdata_f = pd.read_csv("JC-201806-citibike-tripdata.csv")
df_JCcitibike_tripdata_g = pd.read_csv("JC-201807-citibike-tripdata.csv")
df_JCcitibike_tripdata_h = pd.read_csv("JC-201808-citibike-tripdata.csv")
df_JCcitibike_tripdata_i = pd.read_csv("JC-201809-citibike-tripdata.csv")
df_JCcitibike_tripdata_j = pd.read_csv("JC-201810-citibike-tripdata.csv")
df_JCcitibike_tripdata_k = pd.read_csv("JC-201811-citibike-tripdata.csv")
df_JCcitibike_tripdata_l = pd.read_csv("JC-201812-citibike-tripdata.csv")

# %%
print(df_JCcitibike_tripdata_a)
print(df_JCcitibike_tripdata_b)
print(df_JCcitibike_tripdata_c)
print(df_JCcitibike_tripdata_d)
print(df_JCcitibike_tripdata_e)
print(df_JCcitibike_tripdata_f)
print(df_JCcitibike_tripdata_g)
print(df_JCcitibike_tripdata_h)
print(df_JCcitibike_tripdata_i)
print(df_JCcitibike_tripdata_j)
print(df_JCcitibike_tripdata_k)
print(df_JCcitibike_tripdata_l)
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1               550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2               510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3               354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4               250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# ...             ...                       ...                       ...
# 12672           247  2018-01-31 11:03:59.1750  2018-01-31 11:08:07.0570
# 12673           806  2018-01-31 15:34:36.8370  2018-01-31 15:48:03.0280
# 12674          1499  2018-01-31 15:45:09.8000  2018-01-31 16:10:09.4400
# 12675           291  2018-01-31 16:54:11.9480  2018-01-31 16:59:03.5760
# 12676           383  2018-01-31 18:34:50.2950  2018-01-31 18:41:13.7530
#
#        start station id start station name  start station latitude  \
# ...

# %%
yeardf_all_rows = pd.concat([df_JCcitibike_tripdata_a,df_JCcitibike_tripdata_b,df_JCcitibike_tripdata_c,df_JCcitibike_tripdata_d,df_JCcitibike_tripdata_e,df_JCcitibike_tripdata_f,
                            df_JCcitibike_tripdata_g,df_JCcitibike_tripdata_h,df_JCcitibike_tripdata_i,df_JCcitibike_tripdata_j,df_JCcitibike_tripdata_k,df_JCcitibike_tripdata_l])
yeardf_all_rows
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1               550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2               510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3               354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4               250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# ...             ...                       ...                       ...
# 20200          1081  2018-12-22 11:51:46.0600  2018-12-22 12:09:47.4730
# 20201           344  2018-12-25 21:40:09.8660  2018-12-25 21:45:54.2670
# 20202          1233  2018-12-29 12:55:45.9690  2018-12-29 13:16:19.5960
# 20203          1057  2018-12-30 15:32:09.3320  2018-12-30 15:49:46.3510
# 20204           301  2018-12-31 16:34:11.9340  2018-12-31 16:39:13.8340
#
#        start station id start station name  start station latitude  \
# ...

# %%
yeardf_all_rows.to_csv("Datafile/Year.csv", index=False, header=True)
